# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.google.com/search?q=web+analytics&rlz=1C1PRUI_ruRU990RU990&sxsrf=AJOqlzXpoPxPqEi7H3r55sQtWdc3AeRlmQ:1675956340666&ei=dBDlY8qvKK36qwG2rbWYDg&uact=5&oq=web+analytics+jobs&gs_lcp=&sclient=gws-wiz-serp&ibp=htl;jobs&sa=X&ved=2ahUKEwiQuOj134j9AhVNpIsKHegwDDoQudcGKAF6BAgIECc#fpstate=tldetail&htivrt=jobs&htidocid=qvIgcfTc6n4AAAAAAAAAAA%3D%3D'
r = requests.get(url)
soup = BeautifulSoup(r.text,'lxml')
name = soup.find('li', class_='iFjolb gws-plugins-horizon-jobs__li-ed').find('div', class_='h2Zk0d')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9024\2481270230.py in <module>
#       2 r = requests.get(url)
#       3 soup = BeautifulSoup(r.text,'lxml')
# ----> 4 name = soup.find('li', class_='iFjolb gws-plugins-horizon-jobs__li-ed').find('div', class_='h2Zk0d')
#
# AttributeError: 'NoneType' object has no attribute 'find'
